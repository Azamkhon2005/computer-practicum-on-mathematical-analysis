# %% [markdown]
# ## Занятие 3
# ## Математический анализ
# ## Решение нелинейных уравнений в Sympy. Solve и solveset.
# https://docs.sympy.org/latest/modules/solvers/solveset.html

# %%
from sympy import Symbol, symbols, S, solve, solveset, Intersection, Interval, EmptySet, Union, Eq, plot
import sympy
import matplotlib.pyplot as plt
# Продолжим использовать магию
# %matplotlib inline

# %% [markdown]
# ### Задание 1
# Решить уравнение $6x^4 + 9x^3 - 99x^2 - 66x + 360 = 0$ с помощью solve и solveset.

# %%
x = Symbol('x')
eq = 6*x**4 + 9*x**3 -99*x**2 -66*x +360
print("C помощью solve: ")
display(solve(eq))
print("C помощью solveset: ")
display(solveset(eq, domain=S.Reals))
# Out:
# C помощью solve:
# [-4, -5/2, 2, 3]
# C помощью solveset:
# {-4, -5/2, 2, 3}

# %% [markdown]
# ### Задание 2.
# Найти только вещественные решения уравнения $12x^8 + 32x^6 + 21x^4 - 2x^2 - 3 = 0$.

# %%
eq = 12*x**8 + 32*x**6 + 21*x**4 -2*x**2 -3
solveset(eq, domain=S.Reals)
# Out:
# {-sqrt(3)/3, sqrt(3)/3}

# %% [markdown]
# ### Задание 3.
# Решить уравнение $\log_2(\sin(x))=-1$.

# %%
solveset(sympy.log((sympy.sin(x))+1, 2))
# Out:
# Union(ImageSet(Lambda(_n, 2*_n*pi + pi), Integers), ImageSet(Lambda(_n, 2*_n*pi), Integers))

# %% [markdown]
# ### Задание 4.
# Найти решения уравнения $2{\rm tg}^2(x) - 3{\rm tg}(x) - 5 = 0$ на открытом интервале  $(-5\pi/4, 11\pi/4)$.

# %%
eq = 2*sympy.tan(x)**2 - 3*sympy.tan(x) - 5
Intersection(solveset(eq), Interval.open(-5*sympy.pi/4, 11*sympy.pi/4))
# Out:
# {-pi/4, 3*pi/4, 7*pi/4, -pi + atan(5/2), atan(5/2) + pi, atan(5/2) + 2*pi, atan(5/2)}

# %% [markdown]
# ### Задание 5.
# Найти область определения функции $\sqrt{\sin^2 x - 1}$.

# %%
solveset((sympy.sin(x)**2 - 1)**0.5 >=0)
# Out:
# ConditionSet(x, (sin(x)**2 - 1)**0.5 >= 0, Complexes)

# %% [markdown]
# ### Задание 6.
# Найти решение уравнения $\frac{(x^3 + 5 x^2 - 3 x - 15)\ln(x^2 - 3)}{x^2 - 3 x + 2} = 0$. Выполнить проверку подстановкой subs.
# #### Указание.
# Решение нужно разбить на части. Нужно учесть область определения выражения в левой части уравнения.

# %%
print("Oбласть определения:")
print(f" x!= {solveset(x**2-3*x+2)} ")
display(solveset(x**2>3))
print("Решение")
solveset((x**3 + 5*x**2 - 3*x - 15)*(x**2-3))
# Out:
# Oбласть определения:
#  x!= {1, 2}
# ConditionSet(x, x**2 > 3, Complexes)
# Решение
# {-5, -sqrt(3), sqrt(3)}

# %%
eq = (x**3 + 5*x**2 - 3*x - 15) * sympy.ln(x**2-3) / (x**2 - 3*x + 2)
X = list(solveset((x**3 + 5*x**2 - 3*x - 15)*(x**2-3)))
for i in X:
  display(f"for {i}: {eq.subs(x, i)}")
# Out:
# 'for -5: 0'
# 'for sqrt(3): nan'
# 'for -sqrt(3): nan'

# %% [markdown]
# ### Индивидуальное задание.
# Через все точки пересечения графиков функций $f(x)$ и $g(x)$ провести горизонтальные прямые. Изобразить на графике $f(x)$ зеленым цветом, $g(x)$ красным, горизонтальные линии черным.
# Формулы для $f(x)$ и $g(x)$ включить в легенду.

# %%
# 31

eq1 = (38*x**2 - 51*x + 105) / 35
eq2 = 2*x**2 - x + 1
res = solveset(eq1-eq2)
res
# Out:
# {-7/4, 5/4}

# %%
x_limits = (x, min(res) - 1, max(res) + 1)
point1, point2 = [(x0, 3*x0 - 1) for x0 in res]
p = plot(eq1, x_limits, line_color='green', legend=True, label='$(38x^2 -51x + 105)/35$', show=False)
p.append(plot(eq2, x_limits, line_color='red', legend=True, label='$2x^2 - x + 1$', show=False)[0])
p.show()
