# %%
import sympy
from sympy import S, Symbol, symbols, Function, integrate, diff, Curve, plot, plot_parametric, latex, solveset, Interval
from sympy import sin as Sin
from sympy import cos as Cos
from sympy import pi as Pi
# %matplotlib inline

# %% [markdown]
# ## Занятие 11
# ## Математический анализ
# ## Применение интегралов для вычисления площади фигуры и длины дуги
#
# ### Задание 1
# Вычислить площадь фигуры, ограниченной графиками функций $f = 2 + x^2$ и  $g = 2 - x^3$. Построить графики, найти точки пересечения, затем вычислить соответствующие интегралы.

# %%
x = Symbol("x")
f = 2 + x**2
g = 2-x**3
sympy.plot(f, g , legend=True)

# %%
print("Точки пересечения:")
print(*sympy.solve(f-g))
print("Площадь:")
integrate(f-g, (x, -1, 0))
# Out:
# Точки пересечения:
# -1 0
# Площадь:
# 1/12

# %% [markdown]
# ### Задача 2.
# Вычислить площадь фигуры, ограниченной графиком функции $x = \cos^3(t)$, $y = \sin^3(t)$, $0 \le t \le 2\pi$.

# %%
t = Symbol("t")

x = Cos(t)**3
y = Sin(t)**3
print("Площадь фигуры:")
integrate(y*diff(x), (t, 0, 2*Pi))
# Out:
# Площадь фигуры:
# -3*pi/8

# %% [markdown]
# ### Задача 3.
# Вычислить площадь фигуры, ограниченной графиком функции $r = \cos(2\phi)$, $-\frac{\pi}{4} \le \phi \le \frac{\pi}{4}$.

# %%
phi = Symbol("phi")
r = Cos(2*phi)
print("Площадь фигуры:")
integrate(r**2, (phi, -Pi/4, Pi/4))/2
# Out:
# Площадь фигуры:
# pi/8

# %% [markdown]
# ### Задача 4.
# Вычислить длину кривой, заданной уравнением $y^2 = x^3$ при $x$ от 1 до 3.

# %%
x = Symbol("x")
y = sympy.sqrt(x**3)
display(integrate(sympy.sqrt(1 + diff(y)**2), (x, 1, 3)))
# Out:
# -13*sqrt(13)/27 + 31*sqrt(31)/27

# %% [markdown]
# ### Задача 5.
# Вычислить длину кривой, заданной параметрически $x = \frac{3}{2}\cos^3 t $, $y = 3\sin^3 t$.

# %%
t = Symbol("t")
x = S(3)*Cos(t)**3/2
y = 3*Sin(t)**3
integrate(sympy.sqrt(diff(x)**2 + diff(y)**2), t)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-086849969d61> in <cell line: 4>()
#       2 x = S(3)*Cos(t)**3/2
#       3 y = 3*Sin(t)**3
# ----> 4 integrate(sympy.sqrt(diff(x)**2 + diff(y)**2), t)
#
# /usr/local/lib/python3.10/dist-packages/sympy/integrals/integrals.py in integrate(meijerg, conds, risch, heurisch, manual, *args, **kwargs)
#    1565
#    1566     if isinstance(integral, Integral):
# -> 1567         return integral.doit(**doit_flags)
#    1568     else:
#    1569         new_args = [a.doit(**doit_flags) if isinstance(a, Integral) else a
#
# /usr/local/lib/python3.10/dist-packages/sympy/integrals/integrals.py in doit(self, **hints)
#     610                     antideriv = None
#     611                 else:
# --> 612                     antideriv = self._eval_integral(
#     613                         function, xab[0], **eval_kwargs)
#     614                     if antideriv is None and meijerg is True:
#
# /usr/local/lib/python3.10/dist-packages/sympy/integrals/integrals.py in _eval_integral(self, f, x, meijerg, risch, manual, heurisch, conds, final)
#    1082                     try:
#    1083                         if conds == 'piecewise':
# -> 1084                             h = heurisch_wrapper(g, x, hints=[])
#    1085                         else:
#    1086                             h = heurisch_(g, x, hints=[])
#
# /usr/local/lib/python3.10/dist-packages/sympy/integrals/heurisch.py in heurisch_wrapper(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     141         return f*x
#     142
# --> 143     res = heurisch(f, x, rewrite, hints, mappings, retries, degree_offset,
#     144                    unnecessary_permutations, _try_heurisch)
#     145     if not isinstance(res, Basic):
#
# /usr/local/lib/python3.10/dist-packages/sympy/integrals/heurisch.py in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     764     else:
#     765         if retries >= 0:
# --> 766             result = heurisch(f, x, mappings=mappings, rewrite=rewrite, hints=hints, retries=retries - 1, unnecessary_permutations=unnecessary_permutations)
#     767
#     768             if result is not None:
#
# /usr/local/lib/python3.10/dist-packages/sympy/integrals/heurisch.py in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     764     else:
#     765         if retries >= 0:
# --> 766             result = heurisch(f, x, mappings=mappings, rewrite=rewrite, hints=hints, retries=retries - 1, unnecessary_permutations=unnecessary_permutations)
#     767
#     768             if result is not None:
#
# /usr/local/lib/python3.10/dist-packages/sympy/integrals/heurisch.py in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     764     else:
#     765         if retries >= 0:
# --> 766             result = heurisch(f, x, mappings=mappings, rewrite=rewrite, hints=hints, retries=retries - 1, unnecessary_permutations=unnecessary_permutations)
#     767
#     768             if result is not None:
#
# /usr/local/lib/python3.10/dist-packages/sympy/integrals/heurisch.py in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     764     else:
#     765         if retries >= 0:
# --> 766             result = heurisch(f, x, mappings=mappings, rewrite=rewrite, hints=hints, retries=retries - 1, unnecessary_permutations=unnecessary_permutations)
#     767
#     768             if result is not None:
#
# /usr/local/lib/python3.10/dist-packages/sympy/integrals/heurisch.py in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     521     else:
#     522         if not rewrite:
# --> 523             result = heurisch(f, x, rewrite=True, hints=hints,
#     524                 unnecessary_permutations=unnecessary_permutations)
#     525
#
# /usr/local/lib/python3.10/dist-packages/sympy/integrals/heurisch.py in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     747     if not more_free:
#     748         # all free generators are identified in V
# --> 749         solution = _integrate('Q')
#     750
#     751         if solution is None:
#
# /usr/local/lib/python3.10/dist-packages/sympy/integrals/heurisch.py in _integrate(field)
#     695         candidate = poly_part/poly_denom + Add(*log_part) + Add(*atan_part)
#     696         h = F - _derivation(candidate) / denom
# --> 697         raw_numer = h.as_numer_denom()[0]
#     698
#     699         # Rewrite raw_numer as a polynomial in K[coeffs][V] where K is a field
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/add.py in as_numer_denom(self)
#     595         nd = defaultdict(list)
#     596         for f in expr.args:
# --> 597             ni, di = f.as_numer_denom()
#     598             nd[di].append(ni)
#     599
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/mul.py in as_numer_denom(self)
#    1232         # as the order is not guaranteed to be the same once they have
#    1233         # been separated from each other
# -> 1234         numers, denoms = list(zip(*[f.as_numer_denom() for f in self.args]))
#    1235         return self.func(*numers), self.func(*denoms)
#    1236
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/mul.py in <listcomp>(.0)
#    1232         # as the order is not guaranteed to be the same once they have
#    1233         # been separated from each other
# -> 1234         numers, denoms = list(zip(*[f.as_numer_denom() for f in self.args]))
#    1235         return self.func(*numers), self.func(*denoms)
#    1236
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/add.py in as_numer_denom(self)
#     595         nd = defaultdict(list)
#     596         for f in expr.args:
# --> 597             ni, di = f.as_numer_denom()
#     598             nd[di].append(ni)
#     599
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/mul.py in as_numer_denom(self)
#    1232         # as the order is not guaranteed to be the same once they have
#    1233         # been separated from each other
# -> 1234         numers, denoms = list(zip(*[f.as_numer_denom() for f in self.args]))
#    1235         return self.func(*numers), self.func(*denoms)
#    1236
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/mul.py in <listcomp>(.0)
#    1232         # as the order is not guaranteed to be the same once they have
#    1233         # been separated from each other
# -> 1234         numers, denoms = list(zip(*[f.as_numer_denom() for f in self.args]))
#    1235         return self.func(*numers), self.func(*denoms)
#    1236
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/add.py in as_numer_denom(self)
#     595         nd = defaultdict(list)
#     596         for f in expr.args:
# --> 597             ni, di = f.as_numer_denom()
#     598             nd[di].append(ni)
#     599
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/mul.py in as_numer_denom(self)
#    1233         # been separated from each other
#    1234         numers, denoms = list(zip(*[f.as_numer_denom() for f in self.args]))
# -> 1235         return self.func(*numers), self.func(*denoms)
#    1236
#    1237     def as_base_exp(self):
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError as e:
#      74                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/operations.py in __new__(cls, evaluate, _sympify, *args)
#      96             return args[0]
#      97
# ---> 98         c_part, nc_part, order_symbols = cls.flatten(args)
#      99         is_commutative = not nc_part
#     100         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# /usr/local/lib/python3.10/dist-packages/sympy/core/mul.py in flatten(cls, seq)
#     480
#     481         # in c_powers
# --> 482         c_powers = _gather(c_powers)
#     483
#     484         # and in num_exp
#
# KeyboardInterrupt:

# %% [markdown]
# ### Задача 6.
# Вычислить длину кривой, заданной в полярных координатах
# $r = \phi$, $\phi$ от 0 до $2\pi$. Результат вычислить приближенно до 3 знаков после запятой.

# %%
phi = Symbol("phi")

r = phi
l = round(float(integrate((r**2 + diff(r)**2), (phi, 0, 2*Pi))), 3)
print(f"Длина кривой: {l}")
# Out:
# Длина кривой: 88.967

# %% [markdown]
# ### Индивидуальное задание
# Вычислить площадь фигуры, ограниченной графиками функций $f = 2\sin(x)$ и  $g = \cos(2x)$ на интервале  $[0, \pi]$. Построить графики, найти точки пересечения (выделить корни на интервале с помощью intersect и Interval), затем вычислить соответствующие интегралы.
#
# Вариант 31
#
# $$f(x)=2 \cos{\left(4 x \right)}$$
# $$g(x)=\cos{\left(6 x \right)}$$
#
# на интервале $[0.3 \pi;0.7 \pi]$

# %%
x = Symbol("x")
f = 2*Cos(4*x)
g = Cos(6*x)

sympy.plot(f, g , legend=True)

# %%
print(f"Площадь фигуры :{round(float(integrate(f-g, (x, 0.3*Pi, 0.7*Pi))),3)}")
# Out:
# Площадь фигуры :0.392
